# %%
import pandas as pd
import numpy as np
d={
    'A':[1,2,np.nan],
    'B':[5,np.nan,np.nan],
    'C':[1,2,3]
}
df = pd.DataFrame(d)
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis = 0)
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis = 1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value = 'Filling value')
# Out:
#                A              B  C
# 0            1.0            5.0  1
# 1            2.0  Filling value  2
# 2  Filling value  Filling value  3

# %%
import pandas as pd
df = pd.DataFrame(d)
a = df['A'].fillna(value = df['A'].mean())
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
a
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df['A'].fillna(value = df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df.fillna??
df['A'].fillna(value = df['A'].mean(),inplace = True)
df
# Out:
# /tmp/ipykernel_1004/1984539697.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['A'].fillna(value = df['A'].mean(),inplace = True)
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  1.5  NaN  3

# %%
data={
    'Company':['Google','Google','MSFT','FB','FB','IMB'],
    'Person': ['Sam','Nihad','Any','Van','Rakib','Ovi'],
    'Sales': [200, 120, 340, 124, 243, 350]
}
df = pd.DataFrame(data)
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IMB    Ovi    350

# %%
bycomp = df.groupby('Company')
bycomp.sum()
# Out:
#            Person  Sales
# Company
# FB       VanRakib    367
# Google   SamNihad    320
# IMB           Ovi    350
# MSFT          Any    340

# %%
import pandas as pd
bycomp = df.groupby('Company')
bycomp.mean(numeric_only=True)
# Out:
#          Sales
# Company
# FB       183.5
# Google   160.0
# IMB      350.0
# MSFT     340.0

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IMB    Ovi    350

# %%
bycomp = df.groupby('Company')
bycomp.std(numeric_only=True)
# Out:
#              Sales
# Company
# FB       84.145707
# Google   56.568542
# IMB            NaN
# MSFT           NaN

# %%
import pandas as pd
bycomp = df.groupby('Company')
bycomp.mean(numeric_only=True)
# Out:
#          Sales
# Company
# FB       183.5
# Google   160.0
# IMB      350.0
# MSFT     340.0

# %%
df.groupby('Company').count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# Google        2      2
# IMB           1      1
# MSFT          1      1

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IMB    Ovi    350

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean        std    min     25%    50%     75%    max
# Company
# FB        2.0  183.5  84.145707  124.0  153.75  183.5  213.25  243.0
# Google    2.0  160.0  56.568542  120.0  140.00  160.0  180.00  200.0
# IMB       1.0  350.0        NaN  350.0  350.00  350.0  350.00  350.0
# MSFT      1.0  340.0        NaN  340.0  340.00  340.0  340.00  340.0

# %%
import pandas as pd
import numpy as np
df1 = pd.DataFrame(np.random.randint(1,20,size = (4,3)),[1,2,3,4],['X','Y','Z'])
df2 = pd.DataFrame(np.random.randint(20,40,size = (4,3)),[5,6,7,8],['X','Y','Z'])
df3 = pd.DataFrame(np.random.randint(40,60,size = (4,3)),[9,10,11,12],['X','Y','Z'])
df1
# Out:
#     X   Y   Z
# 1  19  16  16
# 2  19  12  16
# 3   3  14  16
# 4   7   9   9

# %%
df2
# Out:
#     X   Y   Z
# 5  33  28  35
# 6  31  23  26
# 7  26  33  20
# 8  34  33  24

# %%
df3
# Out:
#      X   Y   Z
# 9   50  46  45
# 10  58  57  43
# 11  55  43  59
# 12  47  48  41

# %%
frame = [df1,df2,df3]
pd.concat(frame)
# Out:
#      X   Y   Z
# 1   19  16  16
# 2   19  12  16
# 3    3  14  16
# 4    7   9   9
# 5   33  28  35
# 6   31  23  26
# 7   26  33  20
# 8   34  33  24
# 9   50  46  45
# 10  58  57  43
# 11  55  43  59
# 12  47  48  41

# %%
pd.concat(frame,axis = 1)
# Out:
#        X     Y     Z     X     Y     Z     X     Y     Z
# 1   19.0  16.0  16.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2   19.0  12.0  16.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3    3.0  14.0  16.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4    7.0   9.0   9.0   NaN   NaN   NaN   NaN   NaN   NaN
# 5    NaN   NaN   NaN  33.0  28.0  35.0   NaN   NaN   NaN
# 6    NaN   NaN   NaN  31.0  23.0  26.0   NaN   NaN   NaN
# 7    NaN   NaN   NaN  26.0  33.0  20.0   NaN   NaN   NaN
# 8    NaN   NaN   NaN  34.0  33.0  24.0   NaN   NaN   NaN
# 9    NaN   NaN   NaN   NaN   NaN   NaN  50.0  46.0  45.0
# 10   NaN   NaN   NaN   NaN   NaN   NaN  58.0  57.0  43.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN  55.0  43.0  59.0
# 12   NaN   NaN   NaN   NaN   NaN   NaN  47.0  48.0  41.0

# %%
left ={
    'Key':['k0','k1','k2','k3'],
    'A':[10,20,30,40],
    'B':[1,2,3,4]
}
right ={
    'Key':['k0','k1','k2','k3'],
    'C':[100,200,300,400],
    'D':[11,12,13,14]
}
import pandas as pd
left = pd.DataFrame(left)
right = pd.DataFrame(right)
left
# Out:
#   Key   A  B
# 0  k0  10  1
# 1  k1  20  2
# 2  k2  30  3
# 3  k3  40  4

# %%
right
# Out:
#   Key    C   D
# 0  k0  100  11
# 1  k1  200  12
# 2  k2  300  13
# 3  k3  400  14

# %%
pd.merge(left,right,on ='Key')
# Out:
#   Key   A  B    C   D
# 0  k0  10  1  100  11
# 1  k1  20  2  200  12
# 2  k2  30  3  300  13
# 3  k3  40  4  400  14

# %%
left={
    'A':['A0','A1','A2'],
    'B':['B0','B1','B2']
}
right={
    'C':['C0','C1','C2'],
    'D':['D0','D1','D2']
}
left =pd.DataFrame(left, index =['k0','k1','k3'])
right =pd.DataFrame(right, index =['k0','k2','k3'])
left
# Out:
#      A   B
# k0  A0  B0
# k1  A1  B1
# k3  A2  B2

# %%
right
# Out:
#      C   D
# k0  C0  D0
# k2  C1  D1
# k3  C2  D2

# %%
left.join(right, how = 'inner')
# Out:
#      A   B   C   D
# k0  A0  B0  C0  D0
# k3  A2  B2  C2  D2

# %%
df = pd.DataFrame({
    'col1':[111,222,111,444],
    'col2':[1,2,3,4],
    'col3':['abc','def','mno','stu']
})
df
# Out:
#    col1  col2 col3
# 0   111     1  abc
# 1   222     2  def
# 2   111     3  mno
# 3   444     4  stu

# %%
df['col1'].unique()
# Out:
# array([111, 222, 444])

# %%
df['col1'].nunique()
# Out:
# 3

# %%
df['col1'].value_counts()
# Out:
# col1
# 111    2
# 222    1
# 444    1
# Name: count, dtype: int64

# %%
def times2(x):
  return 2*x
df['col2'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col2, dtype: int64

# %%
df['col2'].apply(lambda x: x**2)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col2, dtype: int64

# %%
df = pd.read_excel ('/content/Latest_Data_Science_Salaries.xlsx')
df
# Out:
#                      Job Title Employment Type Experience Level  \
# 0                Data Engineer       Full-Time           Senior
# 1                Data Engineer       Full-Time           Senior
# 2                Data Engineer       Full-Time           Senior
# 3                Data Engineer       Full-Time           Senior
# 4               Data Scientist       Full-Time           Senior
# ...                        ...             ...              ...
# 3295            Data Scientist       Full-Time           Senior
# 3296  Principal Data Scientist       Full-Time              Mid
# 3297            Data Scientist       Full-Time            Entry
# 3298     Business Data Analyst        Contract            Entry
# 3299      Data Science Manager       Full-Time           Senior
#
#      Expertise Level   Salary       Salary Currency Company Location  \
# 0             Expert   210000  United States Dollar    United States
# ...

# %%
df.head()
# Out:
#         Job Title Employment Type Experience Level Expertise Level  Salary  \
# 0   Data Engineer       Full-Time           Senior          Expert  210000
# 1   Data Engineer       Full-Time           Senior          Expert  165000
# 2   Data Engineer       Full-Time           Senior          Expert  185900
# 3   Data Engineer       Full-Time           Senior          Expert  129300
# 4  Data Scientist       Full-Time           Senior          Expert  140000
#
#         Salary Currency Company Location  Salary in USD Employee Residence  \
# 0  United States Dollar    United States         210000      United States
# 1  United States Dollar    United States         165000      United States
# 2  United States Dollar    United States         185900      United States
# 3  United States Dollar    United States         129300      United States
# 4  United States Dollar    United States         140000      United States
#
#   Company Size  Year
# 0       Medium  2023
# ...

# %%
df.tail()
# Out:
#                      Job Title Employment Type Experience Level  \
# 3295            Data Scientist       Full-Time           Senior
# 3296  Principal Data Scientist       Full-Time              Mid
# 3297            Data Scientist       Full-Time            Entry
# 3298     Business Data Analyst        Contract            Entry
# 3299      Data Science Manager       Full-Time           Senior
#
#      Expertise Level   Salary       Salary Currency Company Location  \
# 3295          Expert   412000  United States Dollar    United States
# 3296    Intermediate   151000  United States Dollar    United States
# 3297          Junior   105000  United States Dollar    United States
# 3298          Junior   100000  United States Dollar    United States
# 3299          Expert  7000000          Indian Rupee            India
#
#       Salary in USD Employee Residence Company Size  Year
# 3295         412000      United States        Large  2020
# ...

# %%
df.describe()
# Out:
#              Salary  Salary in USD         Year
# count  3.300000e+03    3300.000000  3300.000000
# mean   2.046623e+05  142095.983939  2022.495455
# std    7.279383e+05   69028.235512     0.716355
# min    1.400000e+04   15000.000000  2020.000000
# 25%    9.416900e+04   90000.000000  2022.000000
# 50%    1.400000e+05  136000.000000  2023.000000
# 75%    1.900000e+05  185000.000000  2023.000000
# max    3.040000e+07  450000.000000  2023.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3300 entries, 0 to 3299
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Job Title           3300 non-null   object
#  1   Employment Type     3300 non-null   object
#  2   Experience Level    3300 non-null   object
#  3   Expertise Level     3300 non-null   object
#  4   Salary              3300 non-null   int64
#  5   Salary Currency     3300 non-null   object
#  6   Company Location    3300 non-null   object
#  7   Salary in USD       3300 non-null   int64
#  8   Employee Residence  3300 non-null   object
#  9   Company Size        3300 non-null   object
#  10  Year                3300 non-null   int64
# dtypes: int64(3), object(8)
# memory usage: 283.7+ KB

# %%
df.columns
# Out:
# Index(['Job Title', 'Employment Type', 'Experience Level', 'Expertise Level',
#        'Salary', 'Salary Currency', 'Company Location', 'Salary in USD',
#        'Employee Residence', 'Company Size', 'Year'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Job Title              111
# Employment Type          4
# Experience Level         4
# Expertise Level          4
# Salary                1071
# Salary Currency         22
# Company Location        71
# Salary in USD         1315
# Employee Residence      83
# Company Size             3
# Year                     4
# dtype: int64

# %%
import pandas as pd
df = pd.read_excel ('/content/Latest_Data_Science_Salaries.xlsx')
df['20% Dis'] = df['Salary in USD'].apply(lambda x: x*0.2)
df
# Out:
#                      Job Title Employment Type Experience Level  \
# 0                Data Engineer       Full-Time           Senior
# 1                Data Engineer       Full-Time           Senior
# 2                Data Engineer       Full-Time           Senior
# 3                Data Engineer       Full-Time           Senior
# 4               Data Scientist       Full-Time           Senior
# ...                        ...             ...              ...
# 3295            Data Scientist       Full-Time           Senior
# 3296  Principal Data Scientist       Full-Time              Mid
# 3297            Data Scientist       Full-Time            Entry
# 3298     Business Data Analyst        Contract            Entry
# 3299      Data Science Manager       Full-Time           Senior
#
#      Expertise Level   Salary       Salary Currency Company Location  \
# 0             Expert   210000  United States Dollar    United States
# ...

# %%
df['20% Dis'] = df['Salary in USD'].apply(lambda x: x*0.2)
df['Payment'] = df['Salary in USD']- df['20% Dis']
df
# Out:
#                      Job Title Employment Type Experience Level  \
# 0                Data Engineer       Full-Time           Senior
# 1                Data Engineer       Full-Time           Senior
# 2                Data Engineer       Full-Time           Senior
# 3                Data Engineer       Full-Time           Senior
# 4               Data Scientist       Full-Time           Senior
# ...                        ...             ...              ...
# 3295            Data Scientist       Full-Time           Senior
# 3296  Principal Data Scientist       Full-Time              Mid
# 3297            Data Scientist       Full-Time            Entry
# 3298     Business Data Analyst        Contract            Entry
# 3299      Data Science Manager       Full-Time           Senior
#
#      Expertise Level   Salary       Salary Currency Company Location  \
# 0             Expert   210000  United States Dollar    United States
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel ('/content/Latest_Data_Science_Salaries.xlsx')
plt.plot(df.groupby('Year')['Salary in USD'].mean(),marker='s')
plt.xlabel('Year')
plt.ylabel('Salary')
plt.show()

# %%
df['Experience Level'].unique()
# Out:
# array(['Senior', 'Mid', 'Executive', 'Entry'], dtype=object)

# %%
df['Salary in USD'].mean()
# Out:
# np.float64(142095.98393939395)

# %%
print("Max Salary:",df['Salary in USD'].max())
print("Min Salary:",df['Salary in USD'].min())
# Out:
# Max Salary: 450000
# Min Salary: 15000

# %%
df[df['Year'].between(2020,2021)]
# Out:
#                             Job Title Employment Type Experience Level  \
# 316   Staff Machine Learning Engineer       Full-Time           Senior
# 317              Staff Data Scientist       Full-Time           Senior
# 618                      Data Analyst       Full-Time            Entry
# 640    Managing Director Data Science       Full-Time        Executive
# 724             Business Data Analyst       Part-Time              Mid
# ...                               ...             ...              ...
# 3295                   Data Scientist       Full-Time           Senior
# 3296         Principal Data Scientist       Full-Time              Mid
# 3297                   Data Scientist       Full-Time            Entry
# 3298            Business Data Analyst        Contract            Entry
# 3299             Data Science Manager       Full-Time           Senior
#
#      Expertise Level   Salary       Salary Currency Company Location  \
# ...

# %%
df.sort_values('Salary in USD')
df.sort_values('Salary in USD',ascending = False)
# Out:
#                                Job Title Employment Type Experience Level  \
# 3085                  Research Scientist       Full-Time              Mid
# 2190                        Data Analyst       Full-Time              Mid
# 1242                  Analytics Engineer       Full-Time              Mid
# 3292  Applied Machine Learning Scientist       Full-Time              Mid
# 1496                        AI Scientist       Full-Time           Senior
# ...                                  ...             ...              ...
# 1696                        Data Analyst       Full-Time           Senior
# 193                         Data Analyst       Full-Time              Mid
# 2826                        Data Analyst       Full-Time            Entry
# 2641          Machine Learning Developer       Full-Time            Entry
# 1335                  Staff Data Analyst       Full-Time        Executive
#
#      Expertise Level   Salary         Salary Currency Company Location  \
# ...

# %%
df['Company Location'].value_counts()
# Out:
# Company Location
# United States           2495
# United Kingdom           251
# Canada                   104
# Germany                   65
# Spain                     47
#                         ...
# Iraq                       1
# New Zealand                1
# Chile                      1
# Moldova, Republic of       1
# Malta                      1
# Name: count, Length: 71, dtype: int64
