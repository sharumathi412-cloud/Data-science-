# %%
x=5
y="John"
print(x)
print(y)
# Out:
# 5
# John

# %%
x = 4
x="sally"
x = 8
print(x)
# Out:
# 8

# %%
x=str(3)
y=int(3)
z=float(3)
print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %%
x=5
y="John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a=4
A="sally"
print(a)
print(A)
# Out:
# 4
# sally

# %%
x,y,z="Algebra","Topology","Real analysis"
print(x)
print(y)
print(z)
# Out:
# Algebra
# Topology
# Real analysis

# %%
x=y=z="Algebra"
print(x)
print(y)
print(z)
# Out:
# Algebra
# Algebra
# Algebra

# %%
flower=["lotus","tulip","sunflower"]
x,y,z=flower
print(x)
print(y)
print(z)
# Out:
# lotus
# tulip
# sunflower

# %%
x="python"
y="is"
z="awesome"
print(x,y,z)
# Out:
# python is awesome

# %%
x=3
y=3.14
z=2j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x=7
print(type(x))
print(x)
# Out:
# <class 'int'>
# 7

# %%
x=3
y=3.2
z=3j
a=float(x)
b=int(y)
c=complex(z)
print(a)
print(b)
print(c)
# Out:
# 3.0
# 3
# 3j

# %%
x=str("s1")
y=str(2)
z=str(3.0)
print(x)
print(y)
print(z)
# Out:
# s1
# 2
# 3.0

# %%
a="Hello"
print(a)
# Out:
# Hello

# %%
a="""life feels better,when you notice the little things."""
print(a)
# Out:
# life feels better,when you notice the little things.

# %%
a="Hello,World!"
print(a[0])
# Out:
# H

# %%
for x in "cherry":
    print(x)
# Out:
# c
# h
# e
# r
# r
# y

# %%
a="Hello,World!"
print(len(a))
# Out:
# 12

# %%
txt="Selflove will never hurts you."
print("hurts" in txt)
# Out:
# True

# %%
txt="Selflove will never hurts you."
if "hurts" in txt:
    print("Yes,'hurts' is present")
# Out:
# Yes,'hurts' is present

# %%
txt="Selflove will never hurts you."
print("free" not in txt)
# Out:
# True

# %%
b="Hello,World!"
print(b[3:6])
# Out:
# lo,

# %%
a=b="Hello'World!"
print(b[:5])
print(b[2:])
print(b[-5:-2])
print(a.upper())
print(a.lower())
# Out:
# Hello
# llo'World!
# orl
# HELLO'WORLD!
# hello'world!

# %%
a="Hello'World!"
print(len(a))
print(a.strip())
print(a.replace ("H","M"))
print(a.split(","))
# Out:
# 12
# Hello'World!
# Mello'World!
# ["Hello'World!"]

# %%
a="Hello"
b="World"
c=a+b
print(c)
# Out:
# HelloWorld

# %%
print(10>9)
print(10==9)
print(10<9)
# Out:
# True
# False
# False

# %%
a=100
b=50
if b>a:
    print("b is greater than a")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a

# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %%
mylist=["apple","banana","kiwi"]
print(mylist)
# Out:
# ['apple', 'banana', 'kiwi']

# %%
thislist=["apple","banana","cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist=["apple","banana","kiwi","cherry","kiwi"]
print(thislist)
# Out:
# ['apple', 'banana', 'kiwi', 'cherry', 'kiwi']

# %%
thislist=["apple","banana","kiwi","cherry"]
print(len(thislist))
# Out:
# 4

# %%
list1=["apple","banana","kiwi","cherry"]
list2=[0,2,4,6,8]
list3=["true","false","true"]
print(list1)
print(list2)
print(list3)
# Out:
# ['apple', 'banana', 'kiwi', 'cherry']
# [0, 2, 4, 6, 8]
# ['true', 'false', 'true']

# %%
mylist=["abc",35,"false",59]
print(mylist)
# Out:
# ['abc', 35, 'false', 59]

# %%
thislist=["apple","banana","melon","jackfruit","mango","kiwi","cherry"]
print(thislist[3])
print(thislist[-2])
print(thislist[2:5])
print(thislist[:6])
print(thislist[-3:-1])
# Out:
# jackfruit
# kiwi
# ['melon', 'jackfruit', 'mango']
# ['apple', 'banana', 'melon', 'jackfruit', 'mango', 'kiwi']
# ['mango', 'kiwi']

# %%
thislist=["apple","banana","cherry"]
thislist.append("orange")
print(thislist)
thislist.insert(2,"orange")
print(thislist)
thislist.remove("apple")
print(thislist)
for x in thislist:
    print(x)
    for i in range(len(thislist)):
        print(thislist[i])
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'banana', 'orange', 'cherry', 'orange']
# ['banana', 'orange', 'cherry', 'orange']
# banana
# banana
# orange
# cherry
# orange
# orange
# banana
# orange
# cherry
# orange
# cherry
# banana
# orange
# cherry
# orange
# orange
# banana
# orange
# cherry
# orange

# %%
mytuple=["apple","banana","cherry"]
thistuple=["apple","banana","cherry"]
print(thistuple)
print(thistuple[1])
print(thistuple[-1])
# Out:
# ['apple', 'banana', 'cherry']
# banana
# cherry

# %%
thisset={"apple","banana","cherry","true",2,3}
print(thisset)
thisset={"apple","banana","cherry"}
print(thisset)
# Out:
# {2, 'banana', 3, 'cherry', 'apple', 'true'}
# {'cherry', 'banana', 'apple'}

# %%
set1={"apple","banana","kiwi","cherry"}
set2={0,2,4,6,8}
set3={"true","false","true"}
print(set1)
print(set2)
print(set3)
# Out:
# {'cherry', 'banana', 'apple', 'kiwi'}
# {0, 2, 4, 6, 8}
# {'true', 'false'}

# %%
myset={"John",35,"false",59}
print(myset)
# Out:
# {35, 'John', 59, 'false'}

# %%
thisset={"apple","banana","cherry"}
for x in thisset:
    print(x)
# Out:
# cherry
# banana
# apple

# %%
set1={"x","y","z"}
set2={1,2,3}
set3=set1.union(set2)
print(set3)
# Out:
# {1, 2, 3, 'z', 'y', 'x'}

# %%
set1={"x","y","z"}
set2={1,2,3}
set3=set1|set2
print(set3)
# Out:
# {1, 2, 3, 'z', 'y', 'x'}

# %%
set1={"x","y","z"}
set2={1,2,3}
set3={"Sebastian","Mia"}
set4={"apple","banana","cherry"}
myset=set1.union(set2,set3,set4)
print(myset)
# Out:
# {1, 2, 3, 'z', 'Mia', 'banana', 'y', 'Sebastian', 'cherry', 'apple', 'x'}

# %%
thisdict={
    "brand":"Fort",
    "model":"Mustang",
    "year":"1964",
    "year":"2020"
}
print(thisdict)
print(len(thisdict))
# Out:
# {'brand': 'Fort', 'model': 'Mustang', 'year': '2020'}
# 3

# %%
thisdict={
    "brand":"Fort",
    "electric":"false",
    "year":"1964",
    "colors":["Black","White","Red"]
}
print(thisdict)
# Out:
# {'brand': 'Fort', 'electric': 'false', 'year': '1964', 'colors': ['Black', 'White', 'Red']}

# %%
thisdict=dict(name="John",age=36,country="Norway")
print(thisdict)
# Out:
# {'name': 'John', 'age': 36, 'country': 'Norway'}

# %%
a=35
b=100
if b>a:
    print("b is greater than a")
# Out:
# b is greater than a

# %%
a=35
b=35
if b>a:
    print("b is greater than a")
elif b==a:
    print("b is equal to a")
# Out:
# b is equal to a

# %%
a=100
b=35
if b>a:
    print("b is greater than a")
elif b==a:
    print("b is equal to a")
else:
    print("a is greater than b")
# Out:
# a is greater than b

# %%
a=100
b=35
if b>a:
    print("b is greater than a")
else:
    print("a is not greater than b")
# Out:
# a is not greater than b

# %%
i=1
while i<6:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=1
while i<6:
    print(i)
    if i==3:
     break
    i+=1
# Out:
# 1
# 2
# 3

# %%
i=0
while i<6:
    i+=1
    if i==3:
     continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
i=1
while i<6:
    print(i)
    i+=1
else:
    print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6

# %%
fruits=["Apple","Banana","Cherry"]
for x in fruits:
    print(x)
# Out:
# Apple
# Banana
# Cherry

# %%
fruits=["Apple","Banana","Cherry"]
for x in fruits:
    print(x)
    if x=="Banana":
        break
# Out:
# Apple
# Banana

# %%
for x in range(7):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for x in range(2,20,2):
    print(x)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %%
for x in range(5,10):
    print(x)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
def my_function(fname):
    print(fname)
my_function("Hello from a function")
# Out:
# Hello from a function

# %%
def my_function(fname):
    print(fname+"Analysis")
my_function("Real")
my_function("Complex")
my_function("Data")
# Out:
# RealAnalysis
# ComplexAnalysis
# DataAnalysis

# %%
def my_function(fname,lname):
    print(fname+" "+lname)
my_function("complex","analysis")
# Out:
# complex analysis

# %%
class Fname:
    x=3
    p=Fname()
    print(p.x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 class Fname:
#       2     x=3
#       3     p=Fname()
#
# Cell In[14], line 3, in Fname()
#       1 class Fname:
#       2     x=3
# ----> 3     p=Fname()
#       4     print(p.x)
#
# NameError: name 'Fname' is not defined

# %%
class Person:
  def __init__(self,name,age):
    self.name=name
    self.age=age
p1=Person("John",36)
print(p1.name)
print(p1.age)
# Out:
# John
# 36

# %%
def myfunc():
  x = 300
  print(x)

myfunc()
# Out:
# 300

# %%
def myfunc():
  x = 300
  def myinnerfunc():
    print(x)
    myinnerfunc()

myfunc()

# %%
x=300
def myfunc():
    print(x)
    
myfunc()

print(x)
# Out:
# 300
# 300

# %%
x=300
def myfunc():
    x=150
    print(x)
    
myfunc()

print(x)
# Out:
# 150
# 300

# %%
def myfunc():
    global x
    x=300
myfunc()

print(x)
# Out:
# 300

# %%
name=input("Enter your name:")
print(f"hello{name}")
# Out:
# Enter your name: Mathi
# helloMathi
